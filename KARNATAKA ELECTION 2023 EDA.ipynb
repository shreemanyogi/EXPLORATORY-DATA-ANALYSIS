# %% [markdown]
# # INTRODUCTION TO THE ANALYSIS
#
# Karnataka is a state in the southwestern region of India. It was formed as Mysore State on 1 November 1956, with the passage of the States Reorganisation Act, and renamed Karnataka in 1973. The state was part of the Carnatic region in British terminology. Its capital and largest city is Bengaluru.
# Legislative Assembly elections were held in Karnataka on 10 May 2023 to elect all 224 members of the Karnataka Legislative Assembly. The votes were counted and the results were declared on 13 May 2023.
# Candidates who win the Assembly elections are called 'Member of Lesgislative Assembly' and hold their seats for five years.
#
# now we analyze election data which we downloaded from indiavotes.com

# %%
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.colors import n_colors
from plotly.subplots import make_subplots

# %% [markdown]
# # lets checkout data

# %%
ka_data= pd.read_excel(r"C:\Users\shrim\OneDrive\Desktop\PROJECTS\EDA\KARNATAKA 2023 ELECTIONS\karnatak_assembly_election_2023.xlsx")
ka_data
# Out:
#        Constituency  Const. No.                Leading Candidate  \
# 0          Afzalpur          34                        M.Y.PATIL
# 1             Aland          46                         Bhojaraj
# 2            Anekal         177                      B. SHIVANNA
# 3          Arabhavi           8  BALACHANDRA LAXMANRAO JARKIHOLI
# 4          Arkalgud         198                         A. MANJU
# ..              ...         ...                              ...
# 219       Yelahanka         150                   S R VISHWANATH
# 220        Yelburga          63              BASAVARAJ RAYAREDDI
# 221        Yellapur          81          ARABAIL HEBBAR SHIVARAM
# 222     Yemkanmardi          10      SATISH LAXMANARAO JARKIHOLI
# 223  Yeshvanthapura         153                  S.T. SOMASHEKAR
#
#                 Leading Party                           Trailing Candidate  \
# 0    Indian National Congress                      NITIN VENKAYYA GUTTEDAR
# ...

# %%
#there are 224 rows and 7 columns.

# %% [markdown]
# # top 10 rows of data

# %%
ka_data.head(10)
# Out:
#    Constituency  Const. No.                Leading Candidate  \
# 0      Afzalpur          34                        M.Y.PATIL
# 1         Aland          46                         Bhojaraj
# 2        Anekal         177                      B. SHIVANNA
# 3      Arabhavi           8  BALACHANDRA LAXMANRAO JARKIHOLI
# 4      Arkalgud         198                         A. MANJU
# 5      Arsikere         194            K.M. SHIVALINGE GOWDA
# 6        Athani           3         LAXMAN. SANGAPPA. SAVADI
# 7         Aurad          52                  PRABHU B CHAVAN
# 8  B.T.M.Layout         172                  RAMALINGA REDDY
# 9   Babaleshwar          29                       M B PATIL.
#
#               Leading Party               Trailing Candidate  \
# 0  Indian National Congress          NITIN VENKAYYA GUTTEDAR
# 1  Indian National Congress                 Subhash Guttedar
# 2  Indian National Congress          SRINIVAS. C. HULLAHALLI
# ...

# %% [markdown]
# # last 10 rows of data

# %%
ka_data.tail(10)
# Out:
#        Constituency  Const. No.            Leading Candidate  \
# 214          Varuna         219                 SIDDARAMAIAH
# 215     Vijay Nagar         167                 M.KRISHNAPPA
# 216    Vijayanagara          90                H.R.GAVIYAPPA
# 217        Virajpet         209                 A.S.PONNANNA
# 218          Yadgir          38     CHANNAREDDY PATIL TUNNUR
# 219       Yelahanka         150               S R VISHWANATH
# 220        Yelburga          63          BASAVARAJ RAYAREDDI
# 221        Yellapur          81      ARABAIL HEBBAR SHIVARAM
# 222     Yemkanmardi          10  SATISH LAXMANARAO JARKIHOLI
# 223  Yeshvanthapura         153              S.T. SOMASHEKAR
#
#                 Leading Party                           Trailing Candidate  \
# 214  Indian National Congress                                   V. SOMANNA
# 215  Indian National Congress                                   H RAVINDRA
# ...

# %% [markdown]
# # Identifying null values

# %%
ka_data.isnull().sum()
# Out:
# Constituency          0
# Const. No.            0
# Leading Candidate     0
# Leading Party         0
# Trailing Candidate    0
# Trailing Party        0
# Margin                0
# dtype: int64

# %% [markdown]
# # renaming columns

# %%
ka_data.rename(columns={"Leading Candidate":"WINNER CANDIDATE", "Leading Party":"WINNING PARTY", "Trailing Candidate":"LOST","Trailing Party":"LOST PARTY"},inplace=True)
ka_data.head(10)
# Out:
#    Constituency  Const. No.                           WINNER  \
# 0      Afzalpur          34                        M.Y.PATIL
# 1         Aland          46                         Bhojaraj
# 2        Anekal         177                      B. SHIVANNA
# 3      Arabhavi           8  BALACHANDRA LAXMANRAO JARKIHOLI
# 4      Arkalgud         198                         A. MANJU
# 5      Arsikere         194            K.M. SHIVALINGE GOWDA
# 6        Athani           3         LAXMAN. SANGAPPA. SAVADI
# 7         Aurad          52                  PRABHU B CHAVAN
# 8  B.T.M.Layout         172                  RAMALINGA REDDY
# 9   Babaleshwar          29                       M B PATIL.
#
#               WINNING PARTY                             LOST  \
# 0  Indian National Congress          NITIN VENKAYYA GUTTEDAR
# 1  Indian National Congress                 Subhash Guttedar
# 2  Indian National Congress          SRINIVAS. C. HULLAHALLI
# ...

# %%
#to know datatypes

ka_data.dtypes
# Out:
# Constituency     object
# Const. No.        int64
# WINNER           object
# WINNING PARTY    object
# LOST             object
# LOST PARTY       object
# Margin            int64
# dtype: object

# %% [markdown]
# # VISUALISATION OF SEATS WON BY EACH PARTY

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='WINNING PARTY', data=ka_data, order=ka_data['WINNING PARTY'].value_counts().index)
plt.title('Number of Seats Won by Each Party in 2023')
plt.xlabel('Party')
plt.ylabel('Number of Seats')
plt.xticks(rotation=45)
plt.show()

# %%
max_margin = ka_data['Margin'].max()
max_margin
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 max_margin = ka_data['Margin'].max()
#       2 max_margin
#
# NameError: name 'ka_data' is not defined
